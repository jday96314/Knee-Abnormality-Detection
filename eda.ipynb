# %% [markdown]
# # Load data

# %%
import polars as pl

train_df = pl.read_csv("data/from_host/train.csv")
train_df.describe()
# Out:
# shape: (9, 15)
# ┌────────────┬────────────┬───────────┬──────────┬───┬───────────┬──────────┬───────────┬──────────┐
# │ statistic  ┆ StudyInsta ┆ Report    ┆ ACL      ┆ … ┆ Synovitis ┆ Baker's  ┆ Contusion ┆ Fracture │
# │ ---        ┆ nceUID     ┆ ---       ┆ ---      ┆   ┆ ---       ┆ ---      ┆ ---       ┆ ---      │
# │ str        ┆ ---        ┆ str       ┆ f64      ┆   ┆ f64       ┆ f64      ┆ f64       ┆ f64      │
# │            ┆ str        ┆           ┆          ┆   ┆           ┆          ┆           ┆          │
# ╞════════════╪════════════╪═══════════╪══════════╪═══╪═══════════╪══════════╪═══════════╪══════════╡
# │ count      ┆ 4407       ┆ 4407      ┆ 58.0     ┆ … ┆ 58.0      ┆ 58.0     ┆ 58.0      ┆ 58.0     │
# │ null_count ┆ 0          ┆ 0         ┆ 4349.0   ┆ … ┆ 4349.0    ┆ 4349.0   ┆ 4349.0    ┆ 4349.0   │
# │ mean       ┆ null       ┆ null      ┆ 0.413793 ┆ … ┆ 0.465517  ┆ 0.206897 ┆ 0.327586  ┆ 0.310345 │
# ...

# %%
train_df.head()
# Out:
# shape: (5, 14)
# ┌─────────────────┬─────────────────┬──────┬──────┬───┬───────────┬─────────┬───────────┬──────────┐
# │ StudyInstanceUI ┆ Report          ┆ ACL  ┆ MCL  ┆ … ┆ Synovitis ┆ Baker's ┆ Contusion ┆ Fracture │
# │ D               ┆ ---             ┆ ---  ┆ ---  ┆   ┆ ---       ┆ ---     ┆ ---       ┆ ---      │
# │ ---             ┆ str             ┆ i64  ┆ i64  ┆   ┆ i64       ┆ i64     ┆ i64       ┆ i64      │
# │ str             ┆                 ┆      ┆      ┆   ┆           ┆         ┆           ┆          │
# ╞═════════════════╪═════════════════╪══════╪══════╪═══╪═══════════╪═════════╪═══════════╪══════════╡
# │ 1.2.826.0.1.368 ┆ Técnica: RMN de ┆ null ┆ null ┆ … ┆ null      ┆ null    ┆ null      ┆ null     │
# │ 0043.8.498.1000 ┆ la rodilla. Re… ┆      ┆      ┆   ┆           ┆         ┆           ┆          │
# │ …               ┆                 ┆      ┆      ┆   ┆           ┆         ┆           ┆          │
# ...
